# %%
# !pip install mplfinance
import mplfinance as mpf
from mplfinance.original_flavor import candlestick_ohlc

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

# %%
# Paso 1: Descargar datos del mercado
def download_stock_data(ticker, start_date, end_date):
    data = yf.download(ticker, start=start_date, end=end_date, interval='15m')
    data['Date'] = data.index
    return data

# Paso 2: Calcular medias móviles
def calculate_moving_averages(data, short_window=20, long_window=50):
    data['SMA'] = data['Close'].rolling(window=short_window).mean()
    data['EMA'] = data['Close'].ewm(span=long_window, adjust=False).mean()
    return data

# Paso 3: Calcular RSI
def calculate_rsi(data, window=14):
    delta = data['Close'].diff(1)
    gain = delta.where(delta > 0, 0)
    loss = -delta.where(delta < 0, 0)

    avg_gain = gain.rolling(window=window).mean()
    avg_loss = loss.rolling(window=window).mean()

    rs = avg_gain / avg_loss
    data['RSI'] = 100 - (100 / (1 + rs))
    return data

# Paso 6: Incorporar IA para predicciones (placeholder para modelo futuro)
def ai_analysis(data):
    # Placeholder: Aquí puedes integrar un modelo de predicción
    # como un modelo de regresión o una red neuronal.
    pass

# Ejecución del bot
def main():
    ticker = "EURUSD=x"  # Cambia esto por cualquier símbolo de acción
    start_date = "2024-12-01"
    end_date = "2024-12-15"

    print("Descargando datos...")
    data = download_stock_data(ticker, start_date, end_date)

    print("Calculando indicadores...")
    data = calculate_moving_averages(data)
    data = calculate_rsi(data)
    data = analyze_volume(data)

    print("Visualizando datos...")
    plot_data(data, ticker)

    print("Análisis de IA...")
    ai_analysis(data)

if __name__ == "__main__":
    main()
# Out:
# Descargando datos...
# /tmp/ipython-input-7-877065709.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start_date, end=end_date, interval='15m')
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['EURUSD=X']: YFPricesMissingError('possibly delisted; no price data found  (15m 2024-12-01 -> 2024-12-15) (Yahoo error = "15m data not available for startTime=1733011200 and endTime=1734220800. The requested range must be within the last 60 days.")')
# Calculando indicadores...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-7-877065709.py in <cell line: 0>()
#      51
#      52 if __name__ == "__main__":
# ---> 53     main()
#
# /tmp/ipython-input-7-877065709.py in main()
# ...
